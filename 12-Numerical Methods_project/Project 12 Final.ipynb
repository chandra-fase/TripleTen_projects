# %% [markdown]
# # Project Description
#
# Rusty Bargain used car sales service is developing an app to attract new customers. In that app, you can quickly find out the market value of your car. You have access to historical data: technical specifications, trim versions, and prices. You need to build the model to determine the value.
#
# Rusty Bargain is interested in:
#
# - the quality of the prediction;
# - the speed of the prediction;
# - the time required for training

# %% [markdown]
# ## Project instructions
# 1.	Download and look at the data.
# 2.	Train different models with various hyperparameters (You should make at least two different models, but more is better. Remember, various implementations of gradient boosting don't count as different models.) The main point of this step is to compare gradient boosting methods with random forest, decision tree, and linear regression.
# 3.	Analyze the speed and quality of the models.
#
# **Notes:**
#  - Use the RMSE metric to evaluate the models.
#  - Linear regression is not very good for hyperparameter tuning, but it is perfect for doing a sanity check of other methods. If gradient boosting performs worse than linear regression, something definitely went wrong.
#  - On your own, work with the LightGBM library and use its tools to build gradient boosting models.
#  - Ideally, your project should include linear regression for a sanity check, a tree-based algorithm with hyperparameter tuning (preferably, random forrest), LightGBM with hyperparameter tuning (try a couple of sets), and CatBoost and XGBoost with hyperparameter tuning (optional).
#  - Take note of the encoding of categorical features for simple algorithms. LightGBM and CatBoost have their implementation, but XGBoost requires OHE.
#  - You can use a special command to find the cell code runtime in Jupyter Notebook. Find that command.
#  - Since the training of a gradient boosting model can take a long time, change only a few model parameters.
#  - If Jupyter Notebook stops working, delete the excessive variables by using the del operator.

# %% [markdown]
# ## Data description
# The dataset is stored in file /datasets/car_data.csv. download dataset.
#
# **Features**
#  - DateCrawled — date profile was downloaded from the database
#  - VehicleType — vehicle body type
#  - RegistrationYear — vehicle registration year
#  - Gearbox — gearbox type
#  - Power — power (hp)
#  - Model — vehicle model
#  - Mileage — mileage (measured in km due to dataset's regional specifics)
#  - RegistrationMonth — vehicle registration month
#  - FuelType — fuel type
#  - Brand — vehicle brand
#  - NotRepaired — vehicle repaired or not
#  - DateCreated — date of profile creation
#  - NumberOfPictures — number of vehicle pictures
#  - PostalCode — postal code of profile owner (user)
#  - LastSeen — date of the last activity of the user
#
# **Target**
#
# Price — price (Euro)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from catboost import CatBoostRegressor, Pool
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import make_scorer
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)
import timeit
from functools import lru_cache

# %% [markdown]
# ## Data preparation

# %%
df = pd.read_csv('/datasets/car_data.csv')
display(df.head())
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %%
display(df.shape)
# Out:
# (354369, 16)

# %%
# renaming columns to snakecase

df = df.rename(columns={'DateCrawled': 'date_crawled', 'Price': 'price', 
                        'VehicleType': 'vehicle_type', 'RegistrationYear': 'registration_year', 
                        'Gearbox': 'gearbox', 'Power': 'power', 'Model': 'model', 'Mileage': 'mileage', 
                        'RegistrationMonth': 'registration_month', 'FuelType': 'fuel_type', 
                        'Brand': 'brand','NotRepaired': 'not_repaired','DateCreated': 'date_created', 
                        'NumberOfPictures': 'num_of_pics', 'PostalCode': 'postal_code', 'LastSeen': 'last_seen'})

# %%
display(df.sample(10))
# Out:
#             date_crawled  price vehicle_type  registration_year gearbox  \
# 327786  09/03/2016 16:53   2650        small               2005  manual
# 293132  10/03/2016 20:58   2750          bus               1984  manual
# 148406  15/03/2016 09:37   9999        sedan               2004    auto
# 216871  11/03/2016 18:43   3100        sedan               2002  manual
# 136986  22/03/2016 20:54   9900        wagon               2005  manual
# 121168  31/03/2016 09:50   6299        wagon               2007  manual
# 325415  27/03/2016 12:38   3250          bus               2004    auto
# 287409  04/04/2016 22:36   7299        wagon               2008    auto
# 285555  05/04/2016 07:51  15550  convertible               2001    auto
# 49532   12/03/2016 18:55   1450        small               2004  manual
#
#         power   model  mileage  registration_month fuel_type          brand  \
# 327786    101   fabia   150000                   8  gasoline          skoda
# 293132     72   other   150000                   1  gasoline  mercedes_benz
# 148406    334      a6   150000                   4    petrol           audi
# 216871     75    golf   150000                   5    petrol     volkswagen
# 136986    224      a6   150000                   8  gasoline           audi
# 121168    109  touran   125000                   7       cng     volkswagen
# 325415    125  zafira   125000                   1    petrol           opel
# 287409    140  passat   150000                   0       NaN     volkswagen
# 285555    306      sl     5000                  11    petrol  mercedes_benz
# 49532     101  fiesta   150000                   5    petrol           ford
#
#        not_repaired      date_created  num_of_pics  postal_code  \
# 327786          NaN  09/03/2016 00:00            0        47918
# 293132           no  10/03/2016 00:00            0        20359
# 148406           no  15/03/2016 00:00            0        12623
# 216871          NaN  11/03/2016 00:00            0        55743
# 136986           no  22/03/2016 00:00            0        54516
# 121168           no  31/03/2016 00:00            0         4316
# 325415           no  27/03/2016 00:00            0        42109
# 287409           no  04/04/2016 00:00            0        47229
# 285555           no  05/04/2016 00:00            0        56072
# 49532           NaN  12/03/2016 00:00            0        50827
#
#                last_seen
# 327786  23/03/2016 08:16
# 293132  15/03/2016 18:46
# 148406  05/04/2016 19:18
# 216871  12/03/2016 08:45
# 136986  06/04/2016 15:17
# 121168  06/04/2016 02:45
# 325415  30/03/2016 17:15
# 287409  07/04/2016 03:17
# 285555  05/04/2016 11:48
# 49532   14/03/2016 11:44

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354369 non-null  object
#  1   price               354369 non-null  int64
#  2   vehicle_type        316879 non-null  object
#  3   registration_year   354369 non-null  int64
#  4   gearbox             334536 non-null  object
#  5   power               354369 non-null  int64
#  6   model               334664 non-null  object
#  7   mileage             354369 non-null  int64
#  8   registration_month  354369 non-null  int64
#  9   fuel_type           321474 non-null  object
#  10  brand               354369 non-null  object
#  11  not_repaired        283215 non-null  object
#  12  date_created        354369 non-null  object
#  13  num_of_pics         354369 non-null  int64
#  14  postal_code         354369 non-null  int64
#  15  last_seen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB
# None

# %%
# checking for missing values

display(df.isna().sum())
display(df.isnull().mean().sort_values(ascending=False))
# Out:
# date_crawled              0
# price                     0
# vehicle_type          37490
# registration_year         0
# gearbox               19833
# power                     0
# model                 19705
# mileage                   0
# registration_month        0
# fuel_type             32895
# brand                     0
# not_repaired          71154
# date_created              0
# num_of_pics               0
# postal_code               0
# last_seen                 0
# dtype: int64
# not_repaired          0.200791
# vehicle_type          0.105794
# fuel_type             0.092827
# gearbox               0.055967
# model                 0.055606
# date_crawled          0.000000
# price                 0.000000
# registration_year     0.000000
# power                 0.000000
# mileage               0.000000
# registration_month    0.000000
# brand                 0.000000
# date_created          0.000000
# num_of_pics           0.000000
# postal_code           0.000000
# last_seen             0.000000
# dtype: float64

# %%
# checking for duplicates

display(df.duplicated().sum())
display(df[df.duplicated()].head())
# Out:
# 262
#            date_crawled  price vehicle_type  registration_year gearbox  power  \
# 14266  21/03/2016 19:06   5999        small               2009  manual     80
# 27568  23/03/2016 10:38  12200          bus               2011  manual    125
# 31599  03/04/2016 20:41   4950        wagon               2003    auto    170
# 33138  07/03/2016 20:45  10900  convertible               2005    auto    163
# 43656  13/03/2016 20:48   4200        sedan               2003  manual    105
#
#           model  mileage  registration_month fuel_type          brand  \
# 14266      polo   125000                   5    petrol     volkswagen
# 27568    zafira    40000                  10  gasoline           opel
# 31599  e_klasse   150000                   4  gasoline  mercedes_benz
# 33138       clk   125000                   5    petrol  mercedes_benz
# 43656      golf   150000                  10  gasoline     volkswagen
#
#       not_repaired      date_created  num_of_pics  postal_code  \
# 14266           no  21/03/2016 00:00            0        65529
# 27568           no  23/03/2016 00:00            0        26629
# 31599           no  03/04/2016 00:00            0        48432
# 33138           no  07/03/2016 00:00            0        61200
# 43656           no  13/03/2016 00:00            0        14482
#
#               last_seen
# 14266  05/04/2016 20:47
# 27568  05/04/2016 07:44
# 31599  05/04/2016 21:17
# 33138  21/03/2016 03:45
# 43656  13/03/2016 20:48

# %%
display(df.describe())
# Out:
#                price  registration_year          power        mileage  \
# count  354369.000000      354369.000000  354369.000000  354369.000000
# mean     4416.656776        2004.234448     110.094337  128211.172535
# std      4514.158514          90.227958     189.850405   37905.341530
# min         0.000000        1000.000000       0.000000    5000.000000
# 25%      1050.000000        1999.000000      69.000000  125000.000000
# 50%      2700.000000        2003.000000     105.000000  150000.000000
# 75%      6400.000000        2008.000000     143.000000  150000.000000
# max     20000.000000        9999.000000   20000.000000  150000.000000
#
#        registration_month  num_of_pics    postal_code
# count       354369.000000     354369.0  354369.000000
# mean             5.714645          0.0   50508.689087
# std              3.726421          0.0   25783.096248
# min              0.000000          0.0    1067.000000
# 25%              3.000000          0.0   30165.000000
# 50%              6.000000          0.0   49413.000000
# 75%              9.000000          0.0   71083.000000
# max             12.000000          0.0   99998.000000

# %%
target = 'price'
features = list(set(df.columns)-set(target))

# %% [markdown]
# **Data Preparation: First Look Summary**
#
#  - Each observation describes a model of a car; there are 354,369 cars and 16 features.
#  - The top two features with missing values are: `'not_repaired'` (20%) and `'vehicle_type'` (11%).
#  - There are 262 duplicated records. This is about 0.07% of the data.
#  - The numerical data shows outliers for the `'price'`, `'registration_year'` and `'power'` columns. It also shows that we have no data in the `'num_of_pics'` column.
#  - The `'date_crawled'`, `'date_created'`, and `'last_seen'` columns are formatted with the wrong datatype.

# %% [markdown]
# ### Fixing the Data

# %%
# getting rid of the duplicates

df.drop_duplicates(inplace=True)

# %%
# correcting the datatypes

df['date_crawled'] = pd.to_datetime(df['date_crawled'], format='%d/%m/%Y %H:%M')
df['date_created'] = pd.to_datetime(df['date_created'], format='%d/%m/%Y %H:%M')
df['last_seen'] = pd.to_datetime(df['last_seen'], format='%d/%m/%Y %H:%M')

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354107 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354107 non-null  datetime64[ns]
#  1   price               354107 non-null  int64
#  2   vehicle_type        316623 non-null  object
#  3   registration_year   354107 non-null  int64
#  4   gearbox             334277 non-null  object
#  5   power               354107 non-null  int64
#  6   model               334406 non-null  object
#  7   mileage             354107 non-null  int64
#  8   registration_month  354107 non-null  int64
#  9   fuel_type           321218 non-null  object
#  10  brand               354107 non-null  object
#  11  not_repaired        282962 non-null  object
#  12  date_created        354107 non-null  datetime64[ns]
#  13  num_of_pics         354107 non-null  int64
#  14  postal_code         354107 non-null  int64
#  15  last_seen           354107 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 45.9+ MB
# None

# %%
display(df['date_crawled'].min(), df['date_crawled'].max())
# Out:
# Timestamp('2016-03-05 14:06:00')
# Timestamp('2016-04-07 14:36:00')

# %%
display(df['date_created'].min(), df['date_created'].max())
# Out:
# Timestamp('2014-03-10 00:00:00')
# Timestamp('2016-04-07 00:00:00')

# %%
display(df['last_seen'].min(), df['last_seen'].max())
# Out:
# Timestamp('2016-03-05 14:15:00')
# Timestamp('2016-04-07 14:58:00')

# %% [markdown]
# **Date  Fields Summary**
#
#  - The data has been crawled for a period of one month.
#  - The `'date_created'` ranges for a period of two years.

# %% [markdown]
# ### Creating a New Field and Date Features

# %%
df['days_on_site'] = (df['last_seen'] - df['date_created']).dt.days
display(np.any(df['days_on_site'] < 0))
# Out:
# False

# %%
df['create_year'] = df['date_created'].dt.year
df['create_month'] = df['date_created'].dt.month
df['create_day'] = df['date_created'].dt.day

# %% [markdown]
# ### Fixing Missing Values
#
# *Thinking about how to impute `'not_repaired'`. It seems that NaN may be a defalut field that someone forgot to change. It is hard to know what the real meaning of this input is. I believe that replace NaN with 'yes' is a more probable meaning of the defualt value.*

# %%
df['not_repaired'] = df['not_repaired'].fillna('yes')
df['not_repaired'] = (df['not_repaired'] == 'yes').astype('int')

# %%
df['gearbox'] = (df['gearbox'] == 'auto').astype('int')

# %%
display(df.isna().sum())
# Out:
# date_crawled              0
# price                     0
# vehicle_type          37484
# registration_year         0
# gearbox                   0
# power                     0
# model                 19701
# mileage                   0
# registration_month        0
# fuel_type             32889
# brand                     0
# not_repaired              0
# date_created              0
# num_of_pics               0
# postal_code               0
# last_seen                 0
# days_on_site              0
# create_year               0
# create_month              0
# create_day                0
# dtype: int64

# %%
def impute_value(in_df, features, target):
  encoders=dict()
  df = in_df.copy()
  for col in df[features].select_dtypes('object').columns:
    df.loc[df[col].isna(), col] = 'None'
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le  
  for col in df[features].select_dtypes('datetime64').columns:
    df[f"{col}_hour"] = df[col].dt.hour
    df[f"{col}_month"] = df[col].dt.month
    df[f"{col}_day"] = df[col].dt.day  
    del df[col]
  features = list(set(df.columns)-set([target]))
  train_df = df[~df[target].isna()]
  test_df = df[df[target].isna()]
  let = LabelEncoder()
  y_train = let.fit_transform(train_df[target])
  y_train = train_df[target].values
  X_train, X_test = train_df[features].values, test_df[features].values
  if len(X_test)==0:
    return in_df
  model = DecisionTreeClassifier().fit(X_train, y_train)
  y_pred = model.predict(X_test)
  df.loc[df[target].isna(), target] = y_pred
  in_df[target] = df[target]
  return in_df

# %%
for col in ['fuel_type', 'vehicle_type', 'model']:
  df = impute_value(df, features=list(set(df.columns)-set([col])-set([target])), target=col)

# %%
display(df.isna().sum())
# Out:
# date_crawled          0
# price                 0
# vehicle_type          0
# registration_year     0
# gearbox               0
# power                 0
# model                 0
# mileage               0
# registration_month    0
# fuel_type             0
# brand                 0
# not_repaired          0
# date_created          0
# num_of_pics           0
# postal_code           0
# last_seen             0
# days_on_site          0
# create_year           0
# create_month          0
# create_day            0
# dtype: int64

# %% [markdown]
# ### Dropping Duplicates

# %%
display(df.duplicated().sum())
# Out:
# 12

# %%
df.drop_duplicates(inplace = True)

# %%
display(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Encoding the Categorical Features

# %%
encode_cols = ['postal_code']
encode_cols += df.select_dtypes(include=['object']).columns.tolist()
oe = OrdinalEncoder()
df[encode_cols] = oe.fit_transform(df[encode_cols])

# %%
display(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Dropping Features Not Used During Modeling

# %%
drop_cols = ['date_crawled', 'date_created', 'num_of_pics', 'last_seen']
df.drop(drop_cols, axis=1, inplace=True)

# %%
display(df.shape)
# Out:
# (354095, 16)

# %%
display(df.head())
# Out:
#    price  vehicle_type  registration_year  gearbox  power  model  mileage  \
# 0    480           5.0               1993        0      0  116.0   150000
# 1  18300           2.0               2011        0    190   30.0   125000
# 2   9800           6.0               2004        1    163  117.0   125000
# 3   1500           5.0               2001        0     75  116.0   150000
# 4   3600           5.0               2008        0     69  101.0    90000
#
#    registration_month  fuel_type  brand  not_repaired  postal_code  \
# 0                   0        6.0   38.0             1       4898.0
# 1                   5        2.0    1.0             1       4615.0
# 2                   8        2.0   14.0             1       6992.0
# 3                   6        6.0   38.0             0       7032.0
# 4                   7        2.0   31.0             0       4212.0
#
#    days_on_site  create_year  create_month  create_day
# 0            14         2016             3          24
# 1            14         2016             3          24
# 2            22         2016             3          14
# 3             0         2016             3          17
# 4             6         2016             3          31

# %%
def convert_dtype(df, field, dtype=np.uint8):
    """
    Convert the dtype
    """
    try:
        df[field] = df[field].astype(dtype)
    except:
        print(f'Failed to change dtype for {field}')

# %%
dtype_cols = {
    'vehicle_type': np.uint8,
    'registration_year': np.uint16,
    'gearbox': np.uint8,
    'power': np.uint8,
    'model': np.uint8,
    'registration_month': np.uint8,
    'fuel_type': np.uint8,
    'brand': np.uint8,
    'not_repaired': np.uint8,
    'postal_code': np.uint32,
    'days_on_site': np.uint16,
    'create_year': np.uint16,
    'create_month': np.uint8,
    'create_day': np.uint8
}

# %%
for col in dtype_cols:
    print(f'Conversion for {col}')
    convert_dtype(df, col, dtype_cols[col])
# Out:
# Conversion for vehicle_type
# Conversion for registration_year
# Conversion for gearbox
# Conversion for power
# Conversion for model
# Conversion for registration_month
# Conversion for fuel_type
# Conversion for brand
# Conversion for not_repaired
# Conversion for postal_code
# Conversion for days_on_site
# Conversion for create_year
# Conversion for create_month
# Conversion for create_day

# %%
# checking dtypes

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 354095 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   price               354095 non-null  int64
#  1   vehicle_type        354095 non-null  uint8
#  2   registration_year   354095 non-null  uint16
#  3   gearbox             354095 non-null  uint8
#  4   power               354095 non-null  uint8
#  5   model               354095 non-null  uint8
#  6   mileage             354095 non-null  int64
#  7   registration_month  354095 non-null  uint8
#  8   fuel_type           354095 non-null  uint8
#  9   brand               354095 non-null  uint8
#  10  not_repaired        354095 non-null  uint8
#  11  postal_code         354095 non-null  uint32
#  12  days_on_site        354095 non-null  uint16
#  13  create_year         354095 non-null  uint16
#  14  create_month        354095 non-null  uint8
#  15  create_day          354095 non-null  uint8
# dtypes: int64(2), uint16(3), uint32(1), uint8(10)
# memory usage: 14.9 MB
# None

# %% [markdown]
# ## Model training

# %%
train_X, test_X, train_y, test_y = train_test_split(df.drop(['price'], axis=1),
                                                      df['price'], test_size=0.2, random_state=1357)
valid_X, test_X, valid_y, test_y = train_test_split(test_X,
                                                      test_y, test_size=0.1, random_state=1357)

# %%
def rmse(y_true, y_pred):
    """
    Make scorer to compute rmse
    """
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def build_model(model, train_X, train_y, valid_X, valid_y, 
                hyperparameters={}, 
                scoring=None, cv=5, model_str=None, cat_features=[], verbose=False):
    """
    Build model
    """
    np.random.seed(1357)
    best_rmse = 0
    start_time = time.time()
    
    gs = GridSearchCV(model, param_grid=hyperparameters, cv=cv, scoring=scoring)
    gs.fit(train_X, train_y)
    if model_str == 'catboost':
        gs.best_estimator_.fit(train_X, train_y, cat_features=cat_features, verbose=verbose)
    else:
        gs.best_estimator_.fit(train_X, train_y)
    preds = gs.best_estimator_.predict(valid_X)
    best_rmse = rmse(valid_y, preds)
    end_time = time.time() - start_time
    return gs.best_estimator_, best_rmse, np.round(end_time, 2)

# %%
lr = LinearRegression()
best_lr_model, best_lr_rmse, best_lr_time = build_model(lr, train_X, train_y, 
                                                        valid_X, valid_y,
                                                        hyperparameters={}, 
                scoring=make_scorer(rmse, greater_is_better=False), cv=5, model_str='lr')

# %%
rf = RandomForestRegressor(random_state=1357)
best_rf_model, best_rf_rmse, best_rf_time = build_model(rf, train_X, train_y, 
                                                        valid_X, valid_y,
                                                        hyperparameters={'n_estimators': [20, 30, 40, 50]}, 
                scoring=make_scorer(rmse, greater_is_better=False), cv=5)

# %%
cat_features = ['vehicle_type',  'gearbox', 'brand',
               'model', 'fuel_type', 'not_repaired', 'create_year', 'create_month', 
               'create_day', 'postal_code']
cat = CatBoostRegressor(learning_rate=0.9, loss_function='RMSE',
                        random_seed=1357)
best_cb_model, best_cb_rmse, best_cb_time = build_model(cat, train_X, train_y, 
                                                        valid_X, valid_y,
                                                        hyperparameters={'iterations': [20, 30, 40, 50]}, 
                scoring=make_scorer(rmse, greater_is_better=False), cv=5, model_str='catboost',
           cat_features=cat_features)
# Out:
# 0:	learn: 2935.1716783	total: 102ms	remaining: 1.94s
# 1:	learn: 2622.0196792	total: 167ms	remaining: 1.5s
# 2:	learn: 2508.0531054	total: 214ms	remaining: 1.21s
# 3:	learn: 2414.9667515	total: 285ms	remaining: 1.14s
# 4:	learn: 2353.3062541	total: 341ms	remaining: 1.02s
# 5:	learn: 2299.3419647	total: 403ms	remaining: 941ms
# 6:	learn: 2252.0715898	total: 466ms	remaining: 866ms
# 7:	learn: 2229.0937277	total: 534ms	remaining: 800ms
# 8:	learn: 2208.5556937	total: 593ms	remaining: 725ms
# 9:	learn: 2166.7577044	total: 659ms	remaining: 659ms
# 10:	learn: 2138.8194440	total: 717ms	remaining: 587ms
# 11:	learn: 2119.6934609	total: 774ms	remaining: 516ms
# 12:	learn: 2110.0292754	total: 825ms	remaining: 444ms
# 13:	learn: 2091.6352953	total: 890ms	remaining: 381ms
# 14:	learn: 2075.7257912	total: 950ms	remaining: 317ms
# 15:	learn: 2059.9497759	total: 1s	remaining: 251ms
# 16:	learn: 2044.2559499	total: 1.07s	remaining: 190ms
# 17:	learn: 2034.9545492	total: 1.14s	remaining: 126ms
# 18:	learn: 2025.2927607	total: 1.19s	remaining: 62.8ms
# 19:	learn: 2021.2710141	total: 1.24s	remaining: 0us
# 0:	learn: 2922.1516618	total: 59.1ms	remaining: 1.12s
# 1:	learn: 2619.3409081	total: 117ms	remaining: 1.05s
# 2:	learn: 2509.6229048	total: 167ms	remaining: 947ms
# 3:	learn: 2430.6380996	total: 227ms	remaining: 908ms
# 4:	learn: 2377.7404907	total: 277ms	remaining: 832ms
# 5:	learn: 2305.0340000	total: 340ms	remaining: 793ms
# 6:	learn: 2267.8162493	total: 401ms	remaining: 744ms
# 7:	learn: 2239.7891153	total: 454ms	remaining: 681ms
# 8:	learn: 2200.1117568	total: 517ms	remaining: 632ms
# 9:	learn: 2170.1159018	total: 575ms	remaining: 575ms
# 10:	learn: 2153.4032200	total: 620ms	remaining: 507ms
# 11:	learn: 2130.8131308	total: 675ms	remaining: 450ms
# 12:	learn: 2118.1971100	total: 737ms	remaining: 397ms
# 13:	learn: 2106.1268469	total: 798ms	remaining: 342ms
# 14:	learn: 2096.6974233	total: 853ms	remaining: 284ms
# 15:	learn: 2087.7365845	total: 914ms	remaining: 229ms
# 16:	learn: 2079.1672326	total: 966ms	remaining: 170ms
# 17:	learn: 2062.8200218	total: 1.03s	remaining: 115ms
# 18:	learn: 2052.6316114	total: 1.09s	remaining: 57.4ms
# 19:	learn: 2046.8844919	total: 1.14s	remaining: 0us
# 0:	learn: 2934.3230492	total: 60.2ms	remaining: 1.14s
# 1:	learn: 2624.9859881	total: 122ms	remaining: 1.1s
# 2:	learn: 2505.5033368	total: 180ms	remaining: 1.02s
# 3:	learn: 2416.0435428	total: 246ms	remaining: 982ms
# 4:	learn: 2347.8579870	total: 301ms	remaining: 903ms
# 5:	learn: 2285.5162371	total: 352ms	remaining: 822ms
# 6:	learn: 2255.3988285	total: 406ms	remaining: 754ms
# 7:	learn: 2224.9365081	total: 470ms	remaining: 705ms
# 8:	learn: 2194.7493388	total: 534ms	remaining: 652ms
# 9:	learn: 2171.8923642	total: 587ms	remaining: 587ms
# 10:	learn: 2154.5863196	total: 646ms	remaining: 529ms
# 11:	learn: 2115.5756108	total: 708ms	remaining: 472ms
# 12:	learn: 2095.9874295	total: 758ms	remaining: 408ms
# 13:	learn: 2085.6027076	total: 819ms	remaining: 351ms
# 14:	learn: 2075.9906512	total: 878ms	remaining: 293ms
# 15:	learn: 2061.1640484	total: 935ms	remaining: 234ms
# 16:	learn: 2052.4320749	total: 993ms	remaining: 175ms
# 17:	learn: 2042.9097207	total: 1.05s	remaining: 117ms
# 18:	learn: 2037.7521590	total: 1.11s	remaining: 58.5ms
# 19:	learn: 2032.5971342	total: 1.16s	remaining: 0us
# 0:	learn: 2929.7277240	total: 61.2ms	remaining: 1.16s
# 1:	learn: 2616.1029746	total: 121ms	remaining: 1.09s
# 2:	learn: 2501.8294934	total: 183ms	remaining: 1.04s
# 3:	learn: 2420.8803614	total: 243ms	remaining: 971ms
# 4:	learn: 2367.5668731	total: 300ms	remaining: 899ms
# 5:	learn: 2319.9219191	total: 354ms	remaining: 826ms
# 6:	learn: 2293.7225342	total: 407ms	remaining: 756ms
# 7:	learn: 2252.2724991	total: 463ms	remaining: 695ms
# 8:	learn: 2227.9757806	total: 528ms	remaining: 645ms
# 9:	learn: 2186.7826292	total: 589ms	remaining: 589ms
# 10:	learn: 2171.3343151	total: 645ms	remaining: 527ms
# 11:	learn: 2149.1939450	total: 707ms	remaining: 472ms
# 12:	learn: 2137.7291088	total: 768ms	remaining: 413ms
# 13:	learn: 2121.3272101	total: 830ms	remaining: 356ms
# 14:	learn: 2107.5324805	total: 890ms	remaining: 297ms
# 15:	learn: 2091.1120888	total: 938ms	remaining: 235ms
# 16:	learn: 2071.1845989	total: 996ms	remaining: 176ms
# 17:	learn: 2059.6513760	total: 1.06s	remaining: 118ms
# 18:	learn: 2048.5015508	total: 1.12s	remaining: 58.9ms
# 19:	learn: 2041.1454415	total: 1.17s	remaining: 0us
# 0:	learn: 2946.4857345	total: 56.5ms	remaining: 1.07s
# 1:	learn: 2636.7714806	total: 119ms	remaining: 1.07s
# 2:	learn: 2518.8126322	total: 173ms	remaining: 981ms
# 3:	learn: 2428.2011119	total: 240ms	remaining: 959ms
# 4:	learn: 2361.4203298	total: 291ms	remaining: 874ms
# 5:	learn: 2296.3073470	total: 347ms	remaining: 810ms
# 6:	learn: 2266.6818796	total: 408ms	remaining: 759ms
# 7:	learn: 2235.4412991	total: 481ms	remaining: 721ms
# 8:	learn: 2219.9981572	total: 542ms	remaining: 662ms
# 9:	learn: 2185.9008413	total: 609ms	remaining: 609ms
# 10:	learn: 2159.8023278	total: 673ms	remaining: 550ms
# 11:	learn: 2125.2343969	total: 739ms	remaining: 493ms
# 12:	learn: 2113.3684704	total: 800ms	remaining: 431ms
# 13:	learn: 2092.7670674	total: 860ms	remaining: 369ms
# 14:	learn: 2081.5956504	total: 917ms	remaining: 306ms
# 15:	learn: 2063.8473200	total: 974ms	remaining: 243ms
# 16:	learn: 2051.9746456	total: 1.03s	remaining: 183ms
# 17:	learn: 2038.3800493	total: 1.1s	remaining: 122ms
# 18:	learn: 2032.3549205	total: 1.16s	remaining: 60.8ms
# 19:	learn: 2024.9772112	total: 1.21s	remaining: 0us
# 0:	learn: 2935.1716783	total: 54.7ms	remaining: 1.59s
# 1:	learn: 2622.0196792	total: 116ms	remaining: 1.63s
# 2:	learn: 2508.0531054	total: 169ms	remaining: 1.52s
# 3:	learn: 2414.9667515	total: 240ms	remaining: 1.56s
# 4:	learn: 2353.3062541	total: 298ms	remaining: 1.49s
# 5:	learn: 2299.3419647	total: 359ms	remaining: 1.44s
# 6:	learn: 2252.0715898	total: 420ms	remaining: 1.38s
# 7:	learn: 2229.0937277	total: 484ms	remaining: 1.33s
# 8:	learn: 2208.5556937	total: 545ms	remaining: 1.27s
# 9:	learn: 2166.7577044	total: 610ms	remaining: 1.22s
# 10:	learn: 2138.8194440	total: 666ms	remaining: 1.15s
# 11:	learn: 2119.6934609	total: 724ms	remaining: 1.09s
# 12:	learn: 2110.0292754	total: 782ms	remaining: 1.02s
# 13:	learn: 2091.6352953	total: 841ms	remaining: 962ms
# 14:	learn: 2075.7257912	total: 899ms	remaining: 899ms
# 15:	learn: 2059.9497759	total: 955ms	remaining: 835ms
# 16:	learn: 2044.2559499	total: 1.02s	remaining: 781ms
# 17:	learn: 2034.9545492	total: 1.09s	remaining: 726ms
# 18:	learn: 2025.2927607	total: 1.14s	remaining: 662ms
# 19:	learn: 2021.2710141	total: 1.19s	remaining: 597ms
# 20:	learn: 2015.3857332	total: 1.26s	remaining: 540ms
# 21:	learn: 2011.9492858	total: 1.31s	remaining: 476ms
# 22:	learn: 2001.7453757	total: 1.37s	remaining: 416ms
# 23:	learn: 1993.4338275	total: 1.43s	remaining: 358ms
# 24:	learn: 1988.7387142	total: 1.49s	remaining: 298ms
# 25:	learn: 1985.6104333	total: 1.55s	remaining: 238ms
# 26:	learn: 1977.8557756	total: 1.6s	remaining: 178ms
# 27:	learn: 1973.9653801	total: 1.66s	remaining: 118ms
# 28:	learn: 1965.2054512	total: 1.73s	remaining: 59.6ms
# 29:	learn: 1963.2210220	total: 1.8s	remaining: 0us
# 0:	learn: 2922.1516618	total: 57.4ms	remaining: 1.66s
# 1:	learn: 2619.3409081	total: 117ms	remaining: 1.63s
# 2:	learn: 2509.6229048	total: 164ms	remaining: 1.47s
# 3:	learn: 2430.6380996	total: 221ms	remaining: 1.44s
# 4:	learn: 2377.7404907	total: 275ms	remaining: 1.38s
# 5:	learn: 2305.0340000	total: 342ms	remaining: 1.37s
# 6:	learn: 2267.8162493	total: 401ms	remaining: 1.32s
# 7:	learn: 2239.7891153	total: 453ms	remaining: 1.25s
# 8:	learn: 2200.1117568	total: 518ms	remaining: 1.21s
# 9:	learn: 2170.1159018	total: 578ms	remaining: 1.16s
# 10:	learn: 2153.4032200	total: 625ms	remaining: 1.08s
# 11:	learn: 2130.8131308	total: 680ms	remaining: 1.02s
# 12:	learn: 2118.1971100	total: 744ms	remaining: 973ms
# 13:	learn: 2106.1268469	total: 801ms	remaining: 915ms
# 14:	learn: 2096.6974233	total: 853ms	remaining: 853ms
# 15:	learn: 2087.7365845	total: 920ms	remaining: 805ms
# 16:	learn: 2079.1672326	total: 971ms	remaining: 743ms
# 17:	learn: 2062.8200218	total: 1.03s	remaining: 690ms
# 18:	learn: 2052.6316114	total: 1.09s	remaining: 633ms
# 19:	learn: 2046.8844919	total: 1.14s	remaining: 571ms
# 20:	learn: 2040.2758330	total: 1.2s	remaining: 515ms
# 21:	learn: 2032.3195904	total: 1.26s	remaining: 459ms
# 22:	learn: 2025.4544445	total: 1.31s	remaining: 399ms
# 23:	learn: 2018.7347912	total: 1.37s	remaining: 343ms
# 24:	learn: 2011.0206457	total: 1.44s	remaining: 289ms
# 25:	learn: 2004.1589658	total: 1.51s	remaining: 233ms
# 26:	learn: 1996.5037140	total: 1.56s	remaining: 174ms
# 27:	learn: 1986.0265095	total: 1.62s	remaining: 116ms
# 28:	learn: 1979.4965532	total: 1.68s	remaining: 58ms
# 29:	learn: 1974.8781714	total: 1.75s	remaining: 0us
# 0:	learn: 2934.3230492	total: 58.3ms	remaining: 1.69s
# 1:	learn: 2624.9859881	total: 124ms	remaining: 1.73s
# 2:	learn: 2505.5033368	total: 177ms	remaining: 1.59s
# 3:	learn: 2416.0435428	total: 241ms	remaining: 1.56s
# 4:	learn: 2347.8579870	total: 296ms	remaining: 1.48s
# 5:	learn: 2285.5162371	total: 347ms	remaining: 1.39s
# 6:	learn: 2255.3988285	total: 402ms	remaining: 1.32s
# 7:	learn: 2224.9365081	total: 467ms	remaining: 1.28s
# 8:	learn: 2194.7493388	total: 530ms	remaining: 1.24s
# 9:	learn: 2171.8923642	total: 581ms	remaining: 1.16s
# 10:	learn: 2154.5863196	total: 645ms	remaining: 1.11s
# 11:	learn: 2115.5756108	total: 707ms	remaining: 1.06s
# 12:	learn: 2095.9874295	total: 760ms	remaining: 994ms
# 13:	learn: 2085.6027076	total: 825ms	remaining: 943ms
# 14:	learn: 2075.9906512	total: 881ms	remaining: 881ms
# 15:	learn: 2061.1640484	total: 945ms	remaining: 826ms
# 16:	learn: 2052.4320749	total: 1s	remaining: 765ms
# 17:	learn: 2042.9097207	total: 1.06s	remaining: 705ms
# 18:	learn: 2037.7521590	total: 1.12s	remaining: 648ms
# 19:	learn: 2032.5971342	total: 1.16s	remaining: 582ms
# 20:	learn: 2025.7771589	total: 1.22s	remaining: 522ms
# 21:	learn: 2012.0132986	total: 1.29s	remaining: 469ms
# 22:	learn: 2008.0999962	total: 1.33s	remaining: 406ms
# 23:	learn: 2003.7249955	total: 1.38s	remaining: 346ms
# 24:	learn: 1995.5047913	total: 1.44s	remaining: 288ms
# 25:	learn: 1984.5713951	total: 1.51s	remaining: 232ms
# 26:	learn: 1979.2931357	total: 1.56s	remaining: 173ms
# 27:	learn: 1972.7304939	total: 1.61s	remaining: 115ms
# 28:	learn: 1969.2790114	total: 1.67s	remaining: 57.6ms
# 29:	learn: 1962.3745818	total: 1.73s	remaining: 0us
# 0:	learn: 2929.7277240	total: 62.2ms	remaining: 1.8s
# 1:	learn: 2616.1029746	total: 119ms	remaining: 1.67s
# 2:	learn: 2501.8294934	total: 179ms	remaining: 1.61s
# 3:	learn: 2420.8803614	total: 239ms	remaining: 1.55s
# 4:	learn: 2367.5668731	total: 296ms	remaining: 1.48s
# 5:	learn: 2319.9219191	total: 350ms	remaining: 1.4s
# 6:	learn: 2293.7225342	total: 401ms	remaining: 1.32s
# 7:	learn: 2252.2724991	total: 459ms	remaining: 1.26s
# 8:	learn: 2227.9757806	total: 525ms	remaining: 1.22s
# 9:	learn: 2186.7826292	total: 584ms	remaining: 1.17s
# 10:	learn: 2171.3343151	total: 635ms	remaining: 1.09s
# 11:	learn: 2149.1939450	total: 700ms	remaining: 1.05s
# 12:	learn: 2137.7291088	total: 763ms	remaining: 997ms
# 13:	learn: 2121.3272101	total: 823ms	remaining: 941ms
# 14:	learn: 2107.5324805	total: 884ms	remaining: 884ms
# 15:	learn: 2091.1120888	total: 934ms	remaining: 817ms
# 16:	learn: 2071.1845989	total: 994ms	remaining: 760ms
# 17:	learn: 2059.6513760	total: 1.06s	remaining: 707ms
# 18:	learn: 2048.5015508	total: 1.11s	remaining: 646ms
# 19:	learn: 2041.1454415	total: 1.16s	remaining: 580ms
# 20:	learn: 2034.9288021	total: 1.23s	remaining: 528ms
# 21:	learn: 2025.4487773	total: 1.29s	remaining: 470ms
# 22:	learn: 2018.1707798	total: 1.35s	remaining: 410ms
# 23:	learn: 2014.9529302	total: 1.4s	remaining: 349ms
# 24:	learn: 2004.1158290	total: 1.47s	remaining: 294ms
# 25:	learn: 1997.4459482	total: 1.53s	remaining: 235ms
# 26:	learn: 1990.2154157	total: 1.6s	remaining: 178ms
# 27:	learn: 1983.1015811	total: 1.67s	remaining: 119ms
# 28:	learn: 1975.6110916	total: 1.73s	remaining: 59.8ms
# 29:	learn: 1971.3682311	total: 1.78s	remaining: 0us
# 0:	learn: 2946.4857345	total: 60.9ms	remaining: 1.76s
# 1:	learn: 2636.7714806	total: 125ms	remaining: 1.76s
# 2:	learn: 2518.8126322	total: 184ms	remaining: 1.66s
# 3:	learn: 2428.2011119	total: 254ms	remaining: 1.65s
# 4:	learn: 2361.4203298	total: 311ms	remaining: 1.56s
# 5:	learn: 2296.3073470	total: 364ms	remaining: 1.45s
# 6:	learn: 2266.6818796	total: 422ms	remaining: 1.39s
# 7:	learn: 2235.4412991	total: 492ms	remaining: 1.35s
# 8:	learn: 2219.9981572	total: 544ms	remaining: 1.27s
# 9:	learn: 2185.9008413	total: 609ms	remaining: 1.22s
# 10:	learn: 2159.8023278	total: 668ms	remaining: 1.15s
# 11:	learn: 2125.2343969	total: 733ms	remaining: 1.1s
# 12:	learn: 2113.3684704	total: 800ms	remaining: 1.05s
# 13:	learn: 2092.7670674	total: 857ms	remaining: 980ms
# 14:	learn: 2081.5956504	total: 915ms	remaining: 915ms
# 15:	learn: 2063.8473200	total: 973ms	remaining: 851ms
# 16:	learn: 2051.9746456	total: 1.03s	remaining: 787ms
# 17:	learn: 2038.3800493	total: 1.1s	remaining: 736ms
# 18:	learn: 2032.3549205	total: 1.15s	remaining: 668ms
# 19:	learn: 2024.9772112	total: 1.2s	remaining: 601ms
# 20:	learn: 2016.7065062	total: 1.27s	remaining: 544ms
# 21:	learn: 2006.7010117	total: 1.33s	remaining: 483ms
# 22:	learn: 2001.0721120	total: 1.39s	remaining: 422ms
# 23:	learn: 1994.7621237	total: 1.45s	remaining: 363ms
# 24:	learn: 1988.5235201	total: 1.5s	remaining: 301ms
# 25:	learn: 1982.0437875	total: 1.57s	remaining: 241ms
# 26:	learn: 1977.4563635	total: 1.62s	remaining: 180ms
# 27:	learn: 1972.0331512	total: 1.68s	remaining: 120ms
# 28:	learn: 1965.7061797	total: 1.74s	remaining: 60.2ms
# 29:	learn: 1959.2124475	total: 1.81s	remaining: 0us
# 0:	learn: 2935.1716783	total: 53.5ms	remaining: 2.08s
# 1:	learn: 2622.0196792	total: 119ms	remaining: 2.26s
# 2:	learn: 2508.0531054	total: 167ms	remaining: 2.06s
# 3:	learn: 2414.9667515	total: 238ms	remaining: 2.14s
# 4:	learn: 2353.3062541	total: 293ms	remaining: 2.05s
# 5:	learn: 2299.3419647	total: 355ms	remaining: 2.01s
# 6:	learn: 2252.0715898	total: 414ms	remaining: 1.95s
# 7:	learn: 2229.0937277	total: 478ms	remaining: 1.91s
# 8:	learn: 2208.5556937	total: 539ms	remaining: 1.86s
# 9:	learn: 2166.7577044	total: 611ms	remaining: 1.83s
# 10:	learn: 2138.8194440	total: 667ms	remaining: 1.76s
# 11:	learn: 2119.6934609	total: 722ms	remaining: 1.69s
# 12:	learn: 2110.0292754	total: 774ms	remaining: 1.61s
# 13:	learn: 2091.6352953	total: 836ms	remaining: 1.55s
# 14:	learn: 2075.7257912	total: 891ms	remaining: 1.49s
# 15:	learn: 2059.9497759	total: 951ms	remaining: 1.43s
# 16:	learn: 2044.2559499	total: 1.02s	remaining: 1.38s
# 17:	learn: 2034.9545492	total: 1.08s	remaining: 1.32s
# 18:	learn: 2025.2927607	total: 1.14s	remaining: 1.26s
# 19:	learn: 2021.2710141	total: 1.19s	remaining: 1.19s
# 20:	learn: 2015.3857332	total: 1.25s	remaining: 1.13s
# 21:	learn: 2011.9492858	total: 1.3s	remaining: 1.07s
# 22:	learn: 2001.7453757	total: 1.36s	remaining: 1.01s
# 23:	learn: 1993.4338275	total: 1.43s	remaining: 951ms
# 24:	learn: 1988.7387142	total: 1.48s	remaining: 888ms
# 25:	learn: 1985.6104333	total: 1.53s	remaining: 826ms
# 26:	learn: 1977.8557756	total: 1.58s	remaining: 763ms
# 27:	learn: 1973.9653801	total: 1.64s	remaining: 702ms
# 28:	learn: 1965.2054512	total: 1.71s	remaining: 650ms
# 29:	learn: 1963.2210220	total: 1.78s	remaining: 593ms
# 30:	learn: 1957.7221722	total: 1.84s	remaining: 534ms
# 31:	learn: 1949.9385205	total: 1.9s	remaining: 475ms
# 32:	learn: 1944.0691415	total: 1.97s	remaining: 417ms
# 33:	learn: 1939.6612516	total: 2.02s	remaining: 357ms
# 34:	learn: 1936.3878356	total: 2.08s	remaining: 297ms
# 35:	learn: 1930.0002638	total: 2.14s	remaining: 238ms
# 36:	learn: 1926.2183433	total: 2.21s	remaining: 179ms
# 37:	learn: 1922.9608418	total: 2.27s	remaining: 119ms
# 38:	learn: 1918.4032247	total: 2.32s	remaining: 59.5ms
# 39:	learn: 1914.4673629	total: 2.38s	remaining: 0us
# 0:	learn: 2922.1516618	total: 56.4ms	remaining: 2.2s
# 1:	learn: 2619.3409081	total: 113ms	remaining: 2.15s
# 2:	learn: 2509.6229048	total: 160ms	remaining: 1.97s
# 3:	learn: 2430.6380996	total: 225ms	remaining: 2.02s
# 4:	learn: 2377.7404907	total: 287ms	remaining: 2.01s
# 5:	learn: 2305.0340000	total: 358ms	remaining: 2.03s
# 6:	learn: 2267.8162493	total: 411ms	remaining: 1.94s
# 7:	learn: 2239.7891153	total: 459ms	remaining: 1.84s
# 8:	learn: 2200.1117568	total: 521ms	remaining: 1.79s
# 9:	learn: 2170.1159018	total: 583ms	remaining: 1.75s
# 10:	learn: 2153.4032200	total: 628ms	remaining: 1.65s
# 11:	learn: 2130.8131308	total: 678ms	remaining: 1.58s
# 12:	learn: 2118.1971100	total: 736ms	remaining: 1.53s
# 13:	learn: 2106.1268469	total: 796ms	remaining: 1.48s
# 14:	learn: 2096.6974233	total: 845ms	remaining: 1.41s
# 15:	learn: 2087.7365845	total: 906ms	remaining: 1.36s
# 16:	learn: 2079.1672326	total: 958ms	remaining: 1.3s
# 17:	learn: 2062.8200218	total: 1.02s	remaining: 1.25s
# 18:	learn: 2052.6316114	total: 1.08s	remaining: 1.19s
# 19:	learn: 2046.8844919	total: 1.13s	remaining: 1.13s
# 20:	learn: 2040.2758330	total: 1.19s	remaining: 1.07s
# 21:	learn: 2032.3195904	total: 1.25s	remaining: 1.02s
# 22:	learn: 2025.4544445	total: 1.3s	remaining: 962ms
# 23:	learn: 2018.7347912	total: 1.37s	remaining: 912ms
# 24:	learn: 2011.0206457	total: 1.43s	remaining: 858ms
# 25:	learn: 2004.1589658	total: 1.5s	remaining: 805ms
# 26:	learn: 1996.5037140	total: 1.55s	remaining: 746ms
# 27:	learn: 1986.0265095	total: 1.61s	remaining: 691ms
# 28:	learn: 1979.4965532	total: 1.66s	remaining: 632ms
# 29:	learn: 1974.8781714	total: 1.73s	remaining: 577ms
# 30:	learn: 1969.7678490	total: 1.78s	remaining: 517ms
# 31:	learn: 1964.0635782	total: 1.83s	remaining: 457ms
# 32:	learn: 1959.6874951	total: 1.88s	remaining: 399ms
# 33:	learn: 1954.5932168	total: 1.94s	remaining: 342ms
# 34:	learn: 1950.8952432	total: 2s	remaining: 287ms
# 35:	learn: 1948.3077404	total: 2.06s	remaining: 229ms
# 36:	learn: 1945.3055846	total: 2.11s	remaining: 171ms
# 37:	learn: 1941.5635971	total: 2.16s	remaining: 114ms
# 38:	learn: 1937.2065282	total: 2.22s	remaining: 57ms
# 39:	learn: 1933.4365707	total: 2.29s	remaining: 0us
# 0:	learn: 2934.3230492	total: 58.3ms	remaining: 2.27s
# 1:	learn: 2624.9859881	total: 126ms	remaining: 2.39s
# 2:	learn: 2505.5033368	total: 176ms	remaining: 2.18s
# 3:	learn: 2416.0435428	total: 242ms	remaining: 2.18s
# 4:	learn: 2347.8579870	total: 293ms	remaining: 2.05s
# 5:	learn: 2285.5162371	total: 347ms	remaining: 1.97s
# 6:	learn: 2255.3988285	total: 402ms	remaining: 1.89s
# 7:	learn: 2224.9365081	total: 467ms	remaining: 1.87s
# 8:	learn: 2194.7493388	total: 535ms	remaining: 1.84s
# 9:	learn: 2171.8923642	total: 587ms	remaining: 1.76s
# 10:	learn: 2154.5863196	total: 645ms	remaining: 1.7s
# 11:	learn: 2115.5756108	total: 706ms	remaining: 1.65s
# 12:	learn: 2095.9874295	total: 759ms	remaining: 1.58s
# 13:	learn: 2085.6027076	total: 820ms	remaining: 1.52s
# 14:	learn: 2075.9906512	total: 879ms	remaining: 1.46s
# 15:	learn: 2061.1640484	total: 938ms	remaining: 1.41s
# 16:	learn: 2052.4320749	total: 992ms	remaining: 1.34s
# 17:	learn: 2042.9097207	total: 1.05s	remaining: 1.28s
# 18:	learn: 2037.7521590	total: 1.11s	remaining: 1.23s
# 19:	learn: 2032.5971342	total: 1.16s	remaining: 1.16s
# 20:	learn: 2025.7771589	total: 1.22s	remaining: 1.1s
# 21:	learn: 2012.0132986	total: 1.28s	remaining: 1.05s
# 22:	learn: 2008.0999962	total: 1.33s	remaining: 987ms
# 23:	learn: 2003.7249955	total: 1.38s	remaining: 921ms
# 24:	learn: 1995.5047913	total: 1.45s	remaining: 868ms
# 25:	learn: 1984.5713951	total: 1.51s	remaining: 815ms
# 26:	learn: 1979.2931357	total: 1.57s	remaining: 755ms
# 27:	learn: 1972.7304939	total: 1.62s	remaining: 696ms
# 28:	learn: 1969.2790114	total: 1.68s	remaining: 637ms
# 29:	learn: 1962.3745818	total: 1.74s	remaining: 579ms
# 30:	learn: 1955.7529856	total: 1.8s	remaining: 524ms
# 31:	learn: 1952.4960757	total: 1.86s	remaining: 464ms
# 32:	learn: 1946.6298526	total: 1.92s	remaining: 406ms
# 33:	learn: 1941.3086203	total: 1.98s	remaining: 349ms
# 34:	learn: 1936.3483387	total: 2.03s	remaining: 290ms
# 35:	learn: 1932.2703471	total: 2.09s	remaining: 232ms
# 36:	learn: 1928.5807702	total: 2.15s	remaining: 174ms
# 37:	learn: 1926.0647339	total: 2.21s	remaining: 116ms
# 38:	learn: 1922.0490755	total: 2.28s	remaining: 58.4ms
# 39:	learn: 1914.8382899	total: 2.33s	remaining: 0us
# 0:	learn: 2929.7277240	total: 61.3ms	remaining: 2.39s
# 1:	learn: 2616.1029746	total: 121ms	remaining: 2.31s
# 2:	learn: 2501.8294934	total: 177ms	remaining: 2.18s
# 3:	learn: 2420.8803614	total: 237ms	remaining: 2.13s
# 4:	learn: 2367.5668731	total: 291ms	remaining: 2.04s
# 5:	learn: 2319.9219191	total: 344ms	remaining: 1.95s
# 6:	learn: 2293.7225342	total: 398ms	remaining: 1.88s
# 7:	learn: 2252.2724991	total: 455ms	remaining: 1.82s
# 8:	learn: 2227.9757806	total: 524ms	remaining: 1.8s
# 9:	learn: 2186.7826292	total: 588ms	remaining: 1.76s
# 10:	learn: 2171.3343151	total: 644ms	remaining: 1.7s
# 11:	learn: 2149.1939450	total: 709ms	remaining: 1.65s
# 12:	learn: 2137.7291088	total: 766ms	remaining: 1.59s
# 13:	learn: 2121.3272101	total: 832ms	remaining: 1.54s
# 14:	learn: 2107.5324805	total: 896ms	remaining: 1.49s
# 15:	learn: 2091.1120888	total: 945ms	remaining: 1.42s
# 16:	learn: 2071.1845989	total: 1s	remaining: 1.36s
# 17:	learn: 2059.6513760	total: 1.07s	remaining: 1.31s
# 18:	learn: 2048.5015508	total: 1.13s	remaining: 1.25s
# 19:	learn: 2041.1454415	total: 1.19s	remaining: 1.19s
# 20:	learn: 2034.9288021	total: 1.25s	remaining: 1.13s
# 21:	learn: 2025.4487773	total: 1.31s	remaining: 1.07s
# 22:	learn: 2018.1707798	total: 1.36s	remaining: 1.01s
# 23:	learn: 2014.9529302	total: 1.41s	remaining: 942ms
# 24:	learn: 2004.1158290	total: 1.48s	remaining: 889ms
# 25:	learn: 1997.4459482	total: 1.55s	remaining: 833ms
# 26:	learn: 1990.2154157	total: 1.61s	remaining: 776ms
# 27:	learn: 1983.1015811	total: 1.67s	remaining: 717ms
# 28:	learn: 1975.6110916	total: 1.74s	remaining: 658ms
# 29:	learn: 1971.3682311	total: 1.79s	remaining: 595ms
# 30:	learn: 1965.8266739	total: 1.84s	remaining: 534ms
# 31:	learn: 1962.9698168	total: 1.9s	remaining: 475ms
# 32:	learn: 1959.6236600	total: 1.96s	remaining: 415ms
# 33:	learn: 1955.6338245	total: 2.02s	remaining: 356ms
# 34:	learn: 1949.5997128	total: 2.07s	remaining: 296ms
# 35:	learn: 1944.4219498	total: 2.13s	remaining: 237ms
# 36:	learn: 1941.0592725	total: 2.19s	remaining: 177ms
# 37:	learn: 1938.5496651	total: 2.24s	remaining: 118ms
# 38:	learn: 1935.8482947	total: 2.3s	remaining: 58.9ms
# 39:	learn: 1932.6687918	total: 2.35s	remaining: 0us
# 0:	learn: 2946.4857345	total: 58.5ms	remaining: 2.28s
# 1:	learn: 2636.7714806	total: 130ms	remaining: 2.46s
# 2:	learn: 2518.8126322	total: 187ms	remaining: 2.3s
# 3:	learn: 2428.2011119	total: 253ms	remaining: 2.28s
# 4:	learn: 2361.4203298	total: 303ms	remaining: 2.12s
# 5:	learn: 2296.3073470	total: 360ms	remaining: 2.04s
# 6:	learn: 2266.6818796	total: 417ms	remaining: 1.97s
# 7:	learn: 2235.4412991	total: 484ms	remaining: 1.94s
# 8:	learn: 2219.9981572	total: 539ms	remaining: 1.85s
# 9:	learn: 2185.9008413	total: 604ms	remaining: 1.81s
# 10:	learn: 2159.8023278	total: 663ms	remaining: 1.75s
# 11:	learn: 2125.2343969	total: 730ms	remaining: 1.7s
# 12:	learn: 2113.3684704	total: 793ms	remaining: 1.65s
# 13:	learn: 2092.7670674	total: 854ms	remaining: 1.58s
# 14:	learn: 2081.5956504	total: 913ms	remaining: 1.52s
# 15:	learn: 2063.8473200	total: 970ms	remaining: 1.45s
# 16:	learn: 2051.9746456	total: 1.03s	remaining: 1.39s
# 17:	learn: 2038.3800493	total: 1.1s	remaining: 1.34s
# 18:	learn: 2032.3549205	total: 1.15s	remaining: 1.27s
# 19:	learn: 2024.9772112	total: 1.2s	remaining: 1.2s
# 20:	learn: 2016.7065062	total: 1.27s	remaining: 1.15s
# 21:	learn: 2006.7010117	total: 1.33s	remaining: 1.09s
# 22:	learn: 2001.0721120	total: 1.38s	remaining: 1.02s
# 23:	learn: 1994.7621237	total: 1.45s	remaining: 967ms
# 24:	learn: 1988.5235201	total: 1.5s	remaining: 902ms
# 25:	learn: 1982.0437875	total: 1.57s	remaining: 844ms
# 26:	learn: 1977.4563635	total: 1.62s	remaining: 781ms
# 27:	learn: 1972.0331512	total: 1.68s	remaining: 719ms
# 28:	learn: 1965.7061797	total: 1.75s	remaining: 662ms
# 29:	learn: 1959.2124475	total: 1.8s	remaining: 602ms
# 30:	learn: 1954.5230217	total: 1.86s	remaining: 542ms
# 31:	learn: 1951.6611022	total: 1.92s	remaining: 481ms
# 32:	learn: 1948.2722666	total: 1.98s	remaining: 420ms
# 33:	learn: 1941.3758233	total: 2.04s	remaining: 360ms
# 34:	learn: 1938.7523771	total: 2.11s	remaining: 301ms
# 35:	learn: 1934.9383212	total: 2.17s	remaining: 241ms
# 36:	learn: 1931.6042188	total: 2.22s	remaining: 180ms
# 37:	learn: 1926.4389204	total: 2.28s	remaining: 120ms
# 38:	learn: 1922.3826792	total: 2.33s	remaining: 59.9ms
# 39:	learn: 1916.0873540	total: 2.38s	remaining: 0us
# 0:	learn: 2935.1716783	total: 51ms	remaining: 2.5s
# 1:	learn: 2622.0196792	total: 105ms	remaining: 2.51s
# 2:	learn: 2508.0531054	total: 151ms	remaining: 2.36s
# 3:	learn: 2414.9667515	total: 219ms	remaining: 2.52s
# 4:	learn: 2353.3062541	total: 272ms	remaining: 2.45s
# 5:	learn: 2299.3419647	total: 331ms	remaining: 2.43s
# 6:	learn: 2252.0715898	total: 387ms	remaining: 2.38s
# 7:	learn: 2229.0937277	total: 451ms	remaining: 2.37s
# 8:	learn: 2208.5556937	total: 520ms	remaining: 2.37s
# 9:	learn: 2166.7577044	total: 580ms	remaining: 2.32s
# 10:	learn: 2138.8194440	total: 634ms	remaining: 2.25s
# 11:	learn: 2119.6934609	total: 687ms	remaining: 2.18s
# 12:	learn: 2110.0292754	total: 739ms	remaining: 2.1s
# 13:	learn: 2091.6352953	total: 803ms	remaining: 2.06s
# 14:	learn: 2075.7257912	total: 863ms	remaining: 2.01s
# 15:	learn: 2059.9497759	total: 919ms	remaining: 1.95s
# 16:	learn: 2044.2559499	total: 986ms	remaining: 1.91s
# 17:	learn: 2034.9545492	total: 1.05s	remaining: 1.86s
# 18:	learn: 2025.2927607	total: 1.1s	remaining: 1.8s
# 19:	learn: 2021.2710141	total: 1.15s	remaining: 1.73s
# 20:	learn: 2015.3857332	total: 1.22s	remaining: 1.68s
# 21:	learn: 2011.9492858	total: 1.27s	remaining: 1.62s
# 22:	learn: 2001.7453757	total: 1.32s	remaining: 1.56s
# 23:	learn: 1993.4338275	total: 1.39s	remaining: 1.51s
# 24:	learn: 1988.7387142	total: 1.44s	remaining: 1.44s
# 25:	learn: 1985.6104333	total: 1.5s	remaining: 1.38s
# 26:	learn: 1977.8557756	total: 1.55s	remaining: 1.32s
# 27:	learn: 1973.9653801	total: 1.61s	remaining: 1.26s
# 28:	learn: 1965.2054512	total: 1.68s	remaining: 1.22s
# 29:	learn: 1963.2210220	total: 1.75s	remaining: 1.17s
# 30:	learn: 1957.7221722	total: 1.8s	remaining: 1.1s
# 31:	learn: 1949.9385205	total: 1.86s	remaining: 1.05s
# 32:	learn: 1944.0691415	total: 1.93s	remaining: 993ms
# 33:	learn: 1939.6612516	total: 1.99s	remaining: 935ms
# 34:	learn: 1936.3878356	total: 2.04s	remaining: 874ms
# 35:	learn: 1930.0002638	total: 2.1s	remaining: 817ms
# 36:	learn: 1926.2183433	total: 2.17s	remaining: 763ms
# 37:	learn: 1922.9608418	total: 2.23s	remaining: 704ms
# 38:	learn: 1918.4032247	total: 2.28s	remaining: 644ms
# 39:	learn: 1914.4673629	total: 2.35s	remaining: 587ms
# 40:	learn: 1910.2160558	total: 2.4s	remaining: 528ms
# 41:	learn: 1907.6896984	total: 2.46s	remaining: 469ms
# 42:	learn: 1903.7254082	total: 2.51s	remaining: 409ms
# 43:	learn: 1900.1646797	total: 2.57s	remaining: 350ms
# 44:	learn: 1897.4709510	total: 2.63s	remaining: 292ms
# 45:	learn: 1893.6822650	total: 2.69s	remaining: 234ms
# 46:	learn: 1888.7579741	total: 2.75s	remaining: 176ms
# 47:	learn: 1885.5610538	total: 2.81s	remaining: 117ms
# 48:	learn: 1881.6095041	total: 2.88s	remaining: 58.8ms
# 49:	learn: 1878.6352129	total: 2.93s	remaining: 0us
# 0:	learn: 2922.1516618	total: 58.5ms	remaining: 2.87s
# 1:	learn: 2619.3409081	total: 116ms	remaining: 2.77s
# 2:	learn: 2509.6229048	total: 165ms	remaining: 2.58s
# 3:	learn: 2430.6380996	total: 218ms	remaining: 2.5s
# 4:	learn: 2377.7404907	total: 272ms	remaining: 2.44s
# 5:	learn: 2305.0340000	total: 333ms	remaining: 2.44s
# 6:	learn: 2267.8162493	total: 393ms	remaining: 2.42s
# 7:	learn: 2239.7891153	total: 443ms	remaining: 2.32s
# 8:	learn: 2200.1117568	total: 506ms	remaining: 2.31s
# 9:	learn: 2170.1159018	total: 567ms	remaining: 2.27s
# 10:	learn: 2153.4032200	total: 610ms	remaining: 2.16s
# 11:	learn: 2130.8131308	total: 662ms	remaining: 2.09s
# 12:	learn: 2118.1971100	total: 721ms	remaining: 2.05s
# 13:	learn: 2106.1268469	total: 778ms	remaining: 2s
# 14:	learn: 2096.6974233	total: 825ms	remaining: 1.93s
# 15:	learn: 2087.7365845	total: 890ms	remaining: 1.89s
# 16:	learn: 2079.1672326	total: 947ms	remaining: 1.84s
# 17:	learn: 2062.8200218	total: 1.01s	remaining: 1.79s
# 18:	learn: 2052.6316114	total: 1.07s	remaining: 1.74s
# 19:	learn: 2046.8844919	total: 1.11s	remaining: 1.67s
# 20:	learn: 2040.2758330	total: 1.17s	remaining: 1.62s
# 21:	learn: 2032.3195904	total: 1.23s	remaining: 1.57s
# 22:	learn: 2025.4544445	total: 1.28s	remaining: 1.51s
# 23:	learn: 2018.7347912	total: 1.35s	remaining: 1.46s
# 24:	learn: 2011.0206457	total: 1.42s	remaining: 1.42s
# 25:	learn: 2004.1589658	total: 1.48s	remaining: 1.36s
# 26:	learn: 1996.5037140	total: 1.53s	remaining: 1.3s
# 27:	learn: 1986.0265095	total: 1.59s	remaining: 1.25s
# 28:	learn: 1979.4965532	total: 1.65s	remaining: 1.19s
# 29:	learn: 1974.8781714	total: 1.72s	remaining: 1.14s
# 30:	learn: 1969.7678490	total: 1.77s	remaining: 1.09s
# 31:	learn: 1964.0635782	total: 1.82s	remaining: 1.02s
# 32:	learn: 1959.6874951	total: 1.88s	remaining: 966ms
# 33:	learn: 1954.5932168	total: 1.93s	remaining: 910ms
# 34:	learn: 1950.8952432	total: 2s	remaining: 858ms
# 35:	learn: 1948.3077404	total: 2.06s	remaining: 801ms
# 36:	learn: 1945.3055846	total: 2.11s	remaining: 741ms
# 37:	learn: 1941.5635971	total: 2.17s	remaining: 684ms
# 38:	learn: 1937.2065282	total: 2.23s	remaining: 628ms
# 39:	learn: 1933.4365707	total: 2.29s	remaining: 572ms
# 40:	learn: 1931.1559648	total: 2.34s	remaining: 513ms
# 41:	learn: 1925.7931490	total: 2.39s	remaining: 456ms
# 42:	learn: 1921.1682686	total: 2.44s	remaining: 398ms
# 43:	learn: 1917.7329709	total: 2.51s	remaining: 342ms
# 44:	learn: 1915.3798071	total: 2.56s	remaining: 285ms
# 45:	learn: 1911.0474159	total: 2.62s	remaining: 228ms
# 46:	learn: 1907.7159942	total: 2.67s	remaining: 170ms
# 47:	learn: 1904.4032325	total: 2.72s	remaining: 113ms
# 48:	learn: 1901.2720387	total: 2.78s	remaining: 56.8ms
# 49:	learn: 1899.0573990	total: 2.83s	remaining: 0us
# 0:	learn: 2934.3230492	total: 56.8ms	remaining: 2.79s
# 1:	learn: 2624.9859881	total: 124ms	remaining: 2.98s
# 2:	learn: 2505.5033368	total: 186ms	remaining: 2.92s
# 3:	learn: 2416.0435428	total: 251ms	remaining: 2.88s
# 4:	learn: 2347.8579870	total: 300ms	remaining: 2.7s
# 5:	learn: 2285.5162371	total: 352ms	remaining: 2.58s
# 6:	learn: 2255.3988285	total: 404ms	remaining: 2.48s
# 7:	learn: 2224.9365081	total: 470ms	remaining: 2.47s
# 8:	learn: 2194.7493388	total: 535ms	remaining: 2.44s
# 9:	learn: 2171.8923642	total: 588ms	remaining: 2.35s
# 10:	learn: 2154.5863196	total: 646ms	remaining: 2.29s
# 11:	learn: 2115.5756108	total: 704ms	remaining: 2.23s
# 12:	learn: 2095.9874295	total: 762ms	remaining: 2.17s
# 13:	learn: 2085.6027076	total: 818ms	remaining: 2.1s
# 14:	learn: 2075.9906512	total: 875ms	remaining: 2.04s
# 15:	learn: 2061.1640484	total: 937ms	remaining: 1.99s
# 16:	learn: 2052.4320749	total: 991ms	remaining: 1.92s
# 17:	learn: 2042.9097207	total: 1.05s	remaining: 1.86s
# 18:	learn: 2037.7521590	total: 1.11s	remaining: 1.81s
# 19:	learn: 2032.5971342	total: 1.16s	remaining: 1.73s
# 20:	learn: 2025.7771589	total: 1.21s	remaining: 1.67s
# 21:	learn: 2012.0132986	total: 1.28s	remaining: 1.63s
# 22:	learn: 2008.0999962	total: 1.32s	remaining: 1.56s
# 23:	learn: 2003.7249955	total: 1.38s	remaining: 1.49s
# 24:	learn: 1995.5047913	total: 1.44s	remaining: 1.44s
# 25:	learn: 1984.5713951	total: 1.51s	remaining: 1.4s
# 26:	learn: 1979.2931357	total: 1.56s	remaining: 1.33s
# 27:	learn: 1972.7304939	total: 1.62s	remaining: 1.27s
# 28:	learn: 1969.2790114	total: 1.68s	remaining: 1.21s
# 29:	learn: 1962.3745818	total: 1.74s	remaining: 1.16s
# 30:	learn: 1955.7529856	total: 1.8s	remaining: 1.1s
# 31:	learn: 1952.4960757	total: 1.85s	remaining: 1.04s
# 32:	learn: 1946.6298526	total: 1.92s	remaining: 987ms
# 33:	learn: 1941.3086203	total: 1.97s	remaining: 929ms
# 34:	learn: 1936.3483387	total: 2.03s	remaining: 871ms
# 35:	learn: 1932.2703471	total: 2.09s	remaining: 814ms
# 36:	learn: 1928.5807702	total: 2.15s	remaining: 757ms
# 37:	learn: 1926.0647339	total: 2.22s	remaining: 701ms
# 38:	learn: 1922.0490755	total: 2.28s	remaining: 643ms
# 39:	learn: 1914.8382899	total: 2.34s	remaining: 584ms
# 40:	learn: 1912.6369919	total: 2.39s	remaining: 524ms
# 41:	learn: 1908.7459491	total: 2.46s	remaining: 468ms
# 42:	learn: 1905.4523508	total: 2.51s	remaining: 409ms
# 43:	learn: 1898.5817112	total: 2.57s	remaining: 351ms
# 44:	learn: 1896.0798746	total: 2.63s	remaining: 292ms
# 45:	learn: 1893.4889104	total: 2.69s	remaining: 234ms
# 46:	learn: 1890.5341944	total: 2.75s	remaining: 175ms
# 47:	learn: 1888.9744291	total: 2.8s	remaining: 117ms
# 48:	learn: 1886.4346249	total: 2.86s	remaining: 58.4ms
# 49:	learn: 1884.3573903	total: 2.91s	remaining: 0us
# 0:	learn: 2929.7277240	total: 61.7ms	remaining: 3.02s
# 1:	learn: 2616.1029746	total: 121ms	remaining: 2.9s
# 2:	learn: 2501.8294934	total: 181ms	remaining: 2.84s
# 3:	learn: 2420.8803614	total: 240ms	remaining: 2.76s
# 4:	learn: 2367.5668731	total: 302ms	remaining: 2.71s
# 5:	learn: 2319.9219191	total: 347ms	remaining: 2.55s
# 6:	learn: 2293.7225342	total: 403ms	remaining: 2.48s
# 7:	learn: 2252.2724991	total: 459ms	remaining: 2.41s
# 8:	learn: 2227.9757806	total: 522ms	remaining: 2.38s
# 9:	learn: 2186.7826292	total: 585ms	remaining: 2.34s
# 10:	learn: 2171.3343151	total: 642ms	remaining: 2.27s
# 11:	learn: 2149.1939450	total: 701ms	remaining: 2.22s
# 12:	learn: 2137.7291088	total: 761ms	remaining: 2.17s
# 13:	learn: 2121.3272101	total: 825ms	remaining: 2.12s
# 14:	learn: 2107.5324805	total: 890ms	remaining: 2.08s
# 15:	learn: 2091.1120888	total: 938ms	remaining: 1.99s
# 16:	learn: 2071.1845989	total: 1s	remaining: 1.95s
# 17:	learn: 2059.6513760	total: 1.07s	remaining: 1.9s
# 18:	learn: 2048.5015508	total: 1.13s	remaining: 1.84s
# 19:	learn: 2041.1454415	total: 1.18s	remaining: 1.76s
# 20:	learn: 2034.9288021	total: 1.24s	remaining: 1.71s
# 21:	learn: 2025.4487773	total: 1.3s	remaining: 1.65s
# 22:	learn: 2018.1707798	total: 1.35s	remaining: 1.59s
# 23:	learn: 2014.9529302	total: 1.4s	remaining: 1.51s
# 24:	learn: 2004.1158290	total: 1.47s	remaining: 1.47s
# 25:	learn: 1997.4459482	total: 1.53s	remaining: 1.41s
# 26:	learn: 1990.2154157	total: 1.6s	remaining: 1.37s
# 27:	learn: 1983.1015811	total: 1.67s	remaining: 1.31s
# 28:	learn: 1975.6110916	total: 1.72s	remaining: 1.25s
# 29:	learn: 1971.3682311	total: 1.77s	remaining: 1.18s
# 30:	learn: 1965.8266739	total: 1.83s	remaining: 1.12s
# 31:	learn: 1962.9698168	total: 1.89s	remaining: 1.06s
# 32:	learn: 1959.6236600	total: 1.95s	remaining: 1s
# 33:	learn: 1955.6338245	total: 2.01s	remaining: 945ms
# 34:	learn: 1949.5997128	total: 2.06s	remaining: 882ms
# 35:	learn: 1944.4219498	total: 2.12s	remaining: 825ms
# 36:	learn: 1941.0592725	total: 2.18s	remaining: 765ms
# 37:	learn: 1938.5496651	total: 2.23s	remaining: 704ms
# 38:	learn: 1935.8482947	total: 2.28s	remaining: 644ms
# 39:	learn: 1932.6687918	total: 2.34s	remaining: 585ms
# 40:	learn: 1930.1122438	total: 2.4s	remaining: 527ms
# 41:	learn: 1925.4730124	total: 2.46s	remaining: 468ms
# 42:	learn: 1922.1034705	total: 2.51s	remaining: 409ms
# 43:	learn: 1920.3849758	total: 2.57s	remaining: 351ms
# 44:	learn: 1913.7624462	total: 2.63s	remaining: 293ms
# 45:	learn: 1909.5688757	total: 2.71s	remaining: 235ms
# 46:	learn: 1906.6012554	total: 2.76s	remaining: 176ms
# 47:	learn: 1903.8778010	total: 2.82s	remaining: 118ms
# 48:	learn: 1901.6842272	total: 2.87s	remaining: 58.6ms
# 49:	learn: 1897.2111285	total: 2.93s	remaining: 0us
# 0:	learn: 2946.4857345	total: 58.9ms	remaining: 2.88s
# 1:	learn: 2636.7714806	total: 123ms	remaining: 2.94s
# 2:	learn: 2518.8126322	total: 177ms	remaining: 2.77s
# 3:	learn: 2428.2011119	total: 244ms	remaining: 2.8s
# 4:	learn: 2361.4203298	total: 298ms	remaining: 2.68s
# 5:	learn: 2296.3073470	total: 348ms	remaining: 2.55s
# 6:	learn: 2266.6818796	total: 403ms	remaining: 2.48s
# 7:	learn: 2235.4412991	total: 470ms	remaining: 2.47s
# 8:	learn: 2219.9981572	total: 523ms	remaining: 2.38s
# 9:	learn: 2185.9008413	total: 591ms	remaining: 2.36s
# 10:	learn: 2159.8023278	total: 649ms	remaining: 2.3s
# 11:	learn: 2125.2343969	total: 716ms	remaining: 2.27s
# 12:	learn: 2113.3684704	total: 780ms	remaining: 2.22s
# 13:	learn: 2092.7670674	total: 836ms	remaining: 2.15s
# 14:	learn: 2081.5956504	total: 891ms	remaining: 2.08s
# 15:	learn: 2063.8473200	total: 942ms	remaining: 2s
# 16:	learn: 2051.9746456	total: 998ms	remaining: 1.94s
# 17:	learn: 2038.3800493	total: 1.07s	remaining: 1.9s
# 18:	learn: 2032.3549205	total: 1.12s	remaining: 1.82s
# 19:	learn: 2024.9772112	total: 1.17s	remaining: 1.76s
# 20:	learn: 2016.7065062	total: 1.24s	remaining: 1.71s
# 21:	learn: 2006.7010117	total: 1.3s	remaining: 1.66s
# 22:	learn: 2001.0721120	total: 1.36s	remaining: 1.59s
# 23:	learn: 1994.7621237	total: 1.42s	remaining: 1.54s
# 24:	learn: 1988.5235201	total: 1.48s	remaining: 1.48s
# 25:	learn: 1982.0437875	total: 1.54s	remaining: 1.42s
# 26:	learn: 1977.4563635	total: 1.6s	remaining: 1.36s
# 27:	learn: 1972.0331512	total: 1.66s	remaining: 1.3s
# 28:	learn: 1965.7061797	total: 1.72s	remaining: 1.25s
# 29:	learn: 1959.2124475	total: 1.79s	remaining: 1.19s
# 30:	learn: 1954.5230217	total: 1.85s	remaining: 1.13s
# 31:	learn: 1951.6611022	total: 1.91s	remaining: 1.07s
# 32:	learn: 1948.2722666	total: 1.97s	remaining: 1.01s
# 33:	learn: 1941.3758233	total: 2.03s	remaining: 957ms
# 34:	learn: 1938.7523771	total: 2.1s	remaining: 899ms
# 35:	learn: 1934.9383212	total: 2.16s	remaining: 840ms
# 36:	learn: 1931.6042188	total: 2.21s	remaining: 775ms
# 37:	learn: 1926.4389204	total: 2.27s	remaining: 717ms
# 38:	learn: 1922.3826792	total: 2.33s	remaining: 656ms
# 39:	learn: 1916.0873540	total: 2.38s	remaining: 595ms
# 40:	learn: 1911.3104253	total: 2.43s	remaining: 534ms
# 41:	learn: 1909.7029403	total: 2.5s	remaining: 476ms
# 42:	learn: 1907.5271117	total: 2.55s	remaining: 415ms
# 43:	learn: 1904.6867665	total: 2.6s	remaining: 355ms
# 44:	learn: 1899.5152756	total: 2.66s	remaining: 295ms
# 45:	learn: 1897.7862820	total: 2.71s	remaining: 235ms
# 46:	learn: 1892.2552393	total: 2.78s	remaining: 177ms
# 47:	learn: 1888.3338067	total: 2.84s	remaining: 118ms
# 48:	learn: 1883.1686967	total: 2.89s	remaining: 59ms
# 49:	learn: 1880.6327551	total: 2.96s	remaining: 0us
# 0:	learn: 2918.5028804	total: 70.6ms	remaining: 3.46s
# 1:	learn: 2626.7181510	total: 141ms	remaining: 3.37s
# 2:	learn: 2487.5696291	total: 211ms	remaining: 3.3s
# 3:	learn: 2426.1756028	total: 273ms	remaining: 3.14s
# 4:	learn: 2374.8092257	total: 353ms	remaining: 3.18s
# 5:	learn: 2319.5065054	total: 429ms	remaining: 3.15s
# 6:	learn: 2248.3324229	total: 500ms	remaining: 3.07s
# 7:	learn: 2225.5547564	total: 559ms	remaining: 2.93s
# 8:	learn: 2200.7438891	total: 624ms	remaining: 2.84s
# 9:	learn: 2167.9514012	total: 696ms	remaining: 2.78s
# 10:	learn: 2153.3052791	total: 783ms	remaining: 2.77s
# 11:	learn: 2140.5652612	total: 843ms	remaining: 2.67s
# 12:	learn: 2127.0759109	total: 918ms	remaining: 2.61s
# 13:	learn: 2115.1274662	total: 989ms	remaining: 2.54s
# 14:	learn: 2100.4600163	total: 1.06s	remaining: 2.48s
# 15:	learn: 2088.8538354	total: 1.13s	remaining: 2.4s
# 16:	learn: 2078.2802534	total: 1.21s	remaining: 2.34s
# 17:	learn: 2066.3994838	total: 1.28s	remaining: 2.28s
# 18:	learn: 2053.6339638	total: 1.35s	remaining: 2.2s
# 19:	learn: 2033.6437944	total: 1.42s	remaining: 2.14s
# 20:	learn: 2026.6592747	total: 1.5s	remaining: 2.06s
# 21:	learn: 2022.4059445	total: 1.55s	remaining: 1.98s
# 22:	learn: 2015.8139050	total: 1.61s	remaining: 1.89s
# 23:	learn: 2011.1377551	total: 1.69s	remaining: 1.83s
# 24:	learn: 2005.9923516	total: 1.76s	remaining: 1.76s
# 25:	learn: 1997.8391716	total: 1.84s	remaining: 1.7s
# 26:	learn: 1993.3746772	total: 1.91s	remaining: 1.63s
# 27:	learn: 1983.1612953	total: 1.99s	remaining: 1.56s
# 28:	learn: 1977.4208385	total: 2.08s	remaining: 1.5s
# 29:	learn: 1974.7114200	total: 2.15s	remaining: 1.44s
# 30:	learn: 1972.1485715	total: 2.22s	remaining: 1.36s
# 31:	learn: 1968.6402494	total: 2.28s	remaining: 1.28s
# 32:	learn: 1960.4889665	total: 2.35s	remaining: 1.21s
# 33:	learn: 1955.2760929	total: 2.41s	remaining: 1.13s
# 34:	learn: 1949.6866029	total: 2.48s	remaining: 1.06s
# 35:	learn: 1945.4627948	total: 2.55s	remaining: 993ms
# 36:	learn: 1942.3187389	total: 2.62s	remaining: 920ms
# 37:	learn: 1936.6261841	total: 2.69s	remaining: 850ms
# 38:	learn: 1931.7763101	total: 2.75s	remaining: 776ms
# 39:	learn: 1928.1847237	total: 2.82s	remaining: 704ms
# 40:	learn: 1923.0517536	total: 2.89s	remaining: 635ms
# 41:	learn: 1918.2278713	total: 2.96s	remaining: 565ms
# 42:	learn: 1914.9181647	total: 3.02s	remaining: 492ms
# 43:	learn: 1912.6412881	total: 3.09s	remaining: 421ms
# 44:	learn: 1910.5008010	total: 3.15s	remaining: 350ms
# 45:	learn: 1905.0939676	total: 3.22s	remaining: 280ms
# 46:	learn: 1900.4046714	total: 3.31s	remaining: 211ms
# 47:	learn: 1895.3324866	total: 3.38s	remaining: 141ms
# 48:	learn: 1891.8779279	total: 3.45s	remaining: 70.4ms
# 49:	learn: 1888.1422953	total: 3.51s	remaining: 0us

# %%
model_results_df = pd.DataFrame({'model': ['LinearRegression', 'RandomForestRegressor', 'CatBoostRegressor'],
              'best_rmse': [best_lr_rmse, best_rf_rmse, best_cb_rmse],
              'train_time': [best_lr_time, best_rf_time, best_cb_time]})

# %%
model_results_df
# Out:
#                    model    best_rmse  train_time
# 0       LinearRegression  3409.077419        2.22
# 1  RandomForestRegressor  1780.134404     1544.81
# 2      CatBoostRegressor  1913.108940       69.75

# %%
# best features from rf model

pd.DataFrame(best_rf_model.feature_importances_, index=df.columns[1:].tolist()).sort_values(0, ascending=False)
# Out:
#                            0
# registration_year   0.525681
# power               0.180397
# brand               0.049744
# model               0.036818
# mileage             0.033201
# vehicle_type        0.032936
# postal_code         0.032415
# days_on_site        0.027056
# registration_month  0.020496
# create_day          0.020078
# gearbox             0.016323
# not_repaired        0.014759
# fuel_type           0.008690
# create_month        0.001402
# create_year         0.000005

# %%
# best features from cb model

pd.DataFrame(best_cb_model.feature_importances_, index=df.columns[1:].tolist()).sort_values(0, ascending=False)
# Out:
#                             0
# registration_year   42.727394
# power               22.906970
# brand               12.844049
# vehicle_type         5.558732
# mileage              4.799621
# model                3.610021
# not_repaired         2.898646
# days_on_site         1.511695
# gearbox              1.451955
# fuel_type            0.934423
# postal_code          0.366641
# registration_month   0.268016
# create_month         0.112823
# create_day           0.009013
# create_year          0.000000

# %% [markdown]
#  - The RandomForestRegressor and CatBoostRegressor were trained using GridSearch with a CrossValidation of 5 folds. For the sake of time, only 1 hyperparameter was tuned - n_estimators/iterations
#  - The RandomForestRegressor has the worst performance with respect to training time; it has taken 1423 seconds. Whereas, LinearRegression took the least amount of time; 2.29 seconds. On the validation set, however, RandomForestRegressor has the best RMSE of EUR 1815
#  - The top 3 important features from RandomForest and CatBoost are: `'registration_year'`, `'power'`, and `'brand'`.

# %% [markdown]
# ## Model analysis

# %% [markdown]
# *Let's check our results.*

# %%
def test_prediction(model, test_X, test_y):
    """
    Predict RMSE on the test set
    """
    start_time = time.time()
    preds = model.predict(test_X)
    return np.round(time.time() - start_time, 2), rmse(test_y, preds)

# %%
models = [best_lr_model, best_rf_model, best_cb_model]
for model in models:
    pred_time, best_rmse = test_prediction(model, test_X, test_y)
    print(f'The RMSE on the test set for {model} is {best_rmse}, and time to predict {pred_time} seconds')
# Out:
# The RMSE on the test set for LinearRegression() is 3319.9717363810455, and time to predict 0.0 seconds
# The RMSE on the test set for RandomForestRegressor(n_estimators=50, random_state=1357) is 1764.6702620752321, and time to predict 0.36 seconds
# The RMSE on the test set for <catboost.core.CatBoostRegressor object at 0x7fecdc323040> is 1908.7739149219926, and time to predict 0.02 seconds

# %% [markdown]
#  - The results of testing the best models on the test set reveal that RandomForestRegressor has the best RMSE; However, the predictions took 0.27 seconds.

# %% [markdown]
# **Summary**
#
#  - RustyBargain will have to make a compromise between a 24x increase in training time versus a +/- 1.1x increase in RMSE should it decide between the top 2 models - RandomForestRegression and CatBoostRegression.
#
#  - However, CatBoostRegressor offers several hyperparameters to play with, and increasing the number of iterations, and adding regularization may help in achieving a better RMSE. Therefore, in my view, they should pick CatBoostRegression simply because it is really fast, and it offers several options to improve the evaluation metric.

# %% [markdown]
# # Checklist

# %% [markdown]
# Type 'x' to check. Then press Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook is open
# - [ ]  Code is error free
# - [ ]  The cells with the code have been arranged in order of execution
# - [ ]  The data has been downloaded and prepared
# - [ ]  The models have been trained
# - [ ]  The analysis of speed and quality of the models has been performed
